# %%
# !git clone https://github.com/GianpieroTulipani/SmilesMVP.git
# %cd SmilesMVP

# !pip install torch-geometric==1.7.2
# !pip install torch-scatter torch-sparse torch-cluster torch-spline-conv -f https://data.pyg.org/whl/torch-$(python -c "import torch; print(torch.__version__)").html
# !pip install deepchem
# !pip install loguru
# !pip install ase

# %cd smilesmvp
# Out:
# Cloning into 'SmilesMVP'...
# remote: Enumerating objects: 426, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 426 (delta 132), reused 73 (delta 53), pack-reused 274 (from 1)
# Receiving objects: 100% (426/426), 11.29 MiB | 41.14 MiB/s, done.
# Resolving deltas: 100% (340/340), done.
# /kaggle/working/SmilesMVP
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.0/223.0 kB 6.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.9/564.9 kB 22.7 MB/s eta 0:00:00
# ...
#   Created wheel for torch-geometric: filename=torch_geometric-1.7.2-py3-none-any.whl size=388117 sha256=700f63a6645d0637d46b990fbac2c4030829d104f59d43fc77834b70f886ac7d
#   Stored in directory: /root/.cache/pip/wheels/c0/55/79/3c3ea6134ca014b6bedf7c47797876dab8fb74774bee58c76a
# Successfully built torch-geometric
# ...
# Looking in links: https://data.pyg.org/whl/torch-2.5.1+cu121.html
# ...

# %%
# !ls /kaggle/input/geom-3d-regression/GEOM_3D_nmol50000_nconf5_nupper1000_morefeat/processed/smiles.csv
# Out:
# /kaggle/input/geom-3d-regression/GEOM_3D_nmol50000_nconf5_nupper1000_morefeat/processed/smiles.csv

# %%
# !python modeling/train.py #CO2 0.0075 for epochs 0.0984 per 13 epoche
# Out:
# Dataset: GEOM_3D_nmol50000_nconf5_nupper1000_morefeat, Total molecules: 250000
# tokenizer_config.json: 100%|███████████████| 1.27k/1.27k [00:00<00:00, 8.90MB/s]
# config.json: 100%|█████████████████████████████| 631/631 [00:00<00:00, 4.87MB/s]
# vocab.json: 100%|██████████████████████████| 6.96k/6.96k [00:00<00:00, 37.4MB/s]
# merges.txt: 100%|█████████████████████████████| 52.0/52.0 [00:00<00:00, 415kB/s]
# tokenizer.json: 100%|██████████████████████| 8.26k/8.26k [00:00<00:00, 37.2MB/s]
# added_tokens.json: 100%|██████████████████████| 25.0/25.0 [00:00<00:00, 162kB/s]
# special_tokens_map.json: 100%|█████████████████| 420/420 [00:00<00:00, 2.77MB/s]
# pytorch_model.bin: 100%|████████████████████| 13.7M/13.7M [00:00<00:00, 138MB/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at DeepChem/ChemBERTa-77M-MLM and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# ...

# %%
# !pip install --upgrade torch-geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 27.6 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: torch-geometric
#     Found existing installation: torch_geometric 1.7.2
#     Uninstalling torch_geometric-1.7.2:
#       Successfully uninstalled torch_geometric-1.7.2
# ...

# %%
# !python modeling/regression_finetuning.py #32 batch, 0.516317 RMSE
# Out:
# tokenizer_config.json: 100%|███████████████| 1.27k/1.27k [00:00<00:00, 7.56MB/s]
# config.json: 100%|█████████████████████████████| 631/631 [00:00<00:00, 4.80MB/s]
# vocab.json: 100%|██████████████████████████| 6.96k/6.96k [00:00<00:00, 40.6MB/s]
# merges.txt: 100%|█████████████████████████████| 52.0/52.0 [00:00<00:00, 395kB/s]
# tokenizer.json: 100%|██████████████████████| 8.26k/8.26k [00:00<00:00, 39.9MB/s]
# added_tokens.json: 100%|██████████████████████| 25.0/25.0 [00:00<00:00, 176kB/s]
# special_tokens_map.json: 100%|█████████████████| 420/420 [00:00<00:00, 3.54MB/s]
# pytorch_model.bin: 100%|████████████████████| 13.7M/13.7M [00:00<00:00, 137MB/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at DeepChem/ChemBERTa-77M-MLM and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...
